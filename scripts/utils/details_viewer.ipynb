# %% [markdown]
# The details file (`.pqt`) can be loaded and viewed as a pandas DataFrame.
#
# You can use the code snippet below. \
# Before running it, start a JupyterLab server by executing run_jupyterlab.sh, then set the notebook kernel by copying and pasting the URL provided by JupyterLab (e.g., `http://localhost:.../lab?token=...`).

# %%
# Setup
import pandas as pd

detail_path = ""
detail_df = pd.read_parquet(detail_path)
detail_df.head()
